# %%
import pandas as pd
import os

# %%
main_dataframe = pd.DataFrame()
main_dataframe_state = pd.DataFrame()

# %% [markdown]
# # <font color="#56b2e3"> INCOME </font>

# %%
# INCOME

directory = '/Users/andresreyes/Downloads/ACS/INCOME'

for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename), low_memory=False, usecols=["SummaryLevel", "AreaName", "B19001_001", "B19326_001", "B19051_001", "B19101_001", "B19113_001", "B19201_001", "B19202_001", "B19301_001"])
        df_new = df[df['SummaryLevel'] == 50]
#         df_new[['County','State']] = df_new.AreaName.str.split(", ",expand=True,)
        main_dataframe = main_dataframe.append(df_new)

# %%
print(main_dataframe)
# Out:
#     SummaryLevel                     AreaName  B19001_001  B19051_001  \
# 12            50     Aitkin County, Minnesota        7640        7640
# 13            50      Anoka County, Minnesota      125260      125260
# 14            50     Becker County, Minnesota       13495       13495
# 15            50   Beltrami County, Minnesota       16906       16906
# 16            50     Benton County, Minnesota       15726       15726
# ..           ...                          ...         ...         ...
# 63            50     Treasure County, Montana         372         372
# 64            50       Valley County, Montana        3350        3350
# 65            50    Wheatland County, Montana         869         869
# 66            50       Wibaux County, Montana         496         496
# 67            50  Yellowstone County, Montana       62459       62459
#
#     B19101_001 B19113_001  B19201_001 B19202_001 B19301_001 B19326_001
# ...

# %%
main_dataframe.columns=['SummaryLevel', 'AreaName', 'Household_Income', 'Median_Income', 'Earnings', 'Family_Income', "Median_Family_Income", "Non_Family_Income", 'Median_Non_Family_Income', 'Per_Capita_Income']

# %%
print(main_dataframe)
# Out:
#     SummaryLevel                     AreaName  Household_Income  \
# 12            50     Aitkin County, Minnesota              7640
# 13            50      Anoka County, Minnesota            125260
# 14            50     Becker County, Minnesota             13495
# 15            50   Beltrami County, Minnesota             16906
# 16            50     Benton County, Minnesota             15726
# ..           ...                          ...               ...
# 63            50     Treasure County, Montana               372
# 64            50       Valley County, Montana              3350
# 65            50    Wheatland County, Montana               869
# 66            50       Wibaux County, Montana               496
# 67            50  Yellowstone County, Montana             62459
#
#     Median_Income  Earnings Family_Income  Median_Family_Income  \
# 12           7640      4992         54400                  2648
# 13         125260     90305         86345                 34955
# ...

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", "B19001_001", "B19326_001", "B19051_001", "B19101_001", "B19113_001", "B19201_001", "B19202_001", "B19301_001"])
main_dataframe_state = main_dataframe_state.append(df)

# %%
print(main_dataframe_state)
# Out:
#    State              AreaName  B19001_001  B19051_001  B19101_001  \
# 0     AL               Alabama     1851061     1851061     1232880
# 1     AK                Alaska      250235      250235      166629
# 2     AZ               Arizona     2448919     2448919     1602188
# 3     AR              Arkansas     1141480     1141480      757729
# 4     CA            California    12807387    12807387     8800019
# 5     CO              Colorado     2051616     2051616     1318973
# 6     CT           Connecticut     1354713     1354713      894413
# 7     DC  District of Columbia      276546      276546      121101
# 8     DE              Delaware      348051      348051      232569
# 9     FL               Florida     7393262     7393262     4759855
# 10    GA               Georgia     3611706     3611706     2443757
# 11    HI                Hawaii      452030      452030      314721
# 12    ID                 Idaho      596107      596107      408281
# ...

# %%
main_dataframe_state.columns=['State', 'AreaName',  'Household_Income', 'Median_Income', 'Earnings', 'Family_Income', "Median_Family_Income", "Non_Family_Income", 'Median_Non_Family_Income', 'Per_Capita_Income']

# %%
print(main_dataframe_state)
# Out:
#    State              AreaName  Household_Income  Median_Income  Earnings  \
# 0     AL               Alabama           1851061        1851061   1232880
# 1     AK                Alaska            250235         250235    166629
# 2     AZ               Arizona           2448919        2448919   1602188
# 3     AR              Arkansas           1141480        1141480    757729
# 4     CA            California          12807387       12807387   8800019
# 5     CO              Colorado           2051616        2051616   1318973
# 6     CT           Connecticut           1354713        1354713    894413
# 7     DC  District of Columbia            276546         276546    121101
# 8     DE              Delaware            348051         348051    232569
# 9     FL               Florida           7393262        7393262   4759855
# 10    GA               Georgia           3611706        3611706   2443757
# 11    HI                Hawaii            452030         452030    314721
# ...

# %% [markdown]
# # <font color="#56b2e3"> AGE </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/AGE'

main_dataframe_age = pd.DataFrame()
main_dataframe_age_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B01001_023', 'B01001_024', 'B01001_025', 'B01001_047', 'B01001_048', 'B01001_049', 'B01002_001', 'B01002_002', 'B01002_003'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_age = main_dataframe_age.append(df_new)

# %%
main_dataframe_age.columns = ['SummaryLevel', 'Male_75_79', 'Male_80_85', 'Male_85_>', 'Female_75_79', 'Female_80_85', 'Female_85_>', 'Median_age_by_sex_for_total_population', 'Median_age_male', 'Median_age_female']

# %%
print(main_dataframe_age)
# Out:
#     SummaryLevel  Male_75_79  Male_80_85  Male_85_>  Female_75_79  \
# 12            50         501         265        179           509
# 13            50        2953        1892       1350          3884
# 14            50         502         348        348           551
# 15            50         437         429        343           601
# 16            50         430         270        315           606
# ..           ...         ...         ...        ...           ...
# 63            50          15           3         14            19
# 64            50         132         107         99           160
# 65            50          44          16         28            18
# 66            50          33          39         19            28
# 67            50        1725        1296       1249          2355
#
#     Female_80_85  Female_85_> Median_age_by_sex_for_total_population  \
# 12           246          235                                   53.6
# ...

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B01001_023', 'B01001_024', 'B01001_025', 'B01001_047', 'B01001_048', 'B01001_049', 'B01002_001', 'B01002_002', 'B01002_003'])
main_dataframe_age_state = main_dataframe_age_state.append(df)
main_dataframe_age_state.columns = ['State', 'AreaName', 'Male_75_79', 'Male_80_85', 'Male_85_>', 'Female_75_79', 'Female_80_85', 'Female_85_>', 'Median_age_by_sex_for_total_population', 'Median_age_male', 'Median_age_female']

# %%
print(main_dataframe)
# Out:
#     SummaryLevel                     AreaName  Household_Income  \
# 12            50     Aitkin County, Minnesota              7640
# 13            50      Anoka County, Minnesota            125260
# 14            50     Becker County, Minnesota             13495
# 15            50   Beltrami County, Minnesota             16906
# 16            50     Benton County, Minnesota             15726
# ..           ...                          ...               ...
# 63            50     Treasure County, Montana               372
# 64            50       Valley County, Montana              3350
# 65            50    Wheatland County, Montana               869
# 66            50       Wibaux County, Montana               496
# 67            50  Yellowstone County, Montana             62459
#
#     Median_Income  Earnings Family_Income  Median_Family_Income  \
# 12           7640      4992         54400                  2648
# 13         125260     90305         86345                 34955
# ...

# %%
main_dataframe['Male_75_79'] = main_dataframe_age['Male_75_79']
main_dataframe['Male_80_85'] = main_dataframe_age['Male_80_85']
main_dataframe['Male_85_>'] = main_dataframe_age['Male_85_>']
main_dataframe['Female_75_79'] = main_dataframe_age['Female_75_79']
main_dataframe['Female_80_85'] = main_dataframe_age['Female_80_85']
main_dataframe['Female_85_>'] = main_dataframe_age['Female_85_>']
main_dataframe['Median_age_by_sex_for_total_population'] = main_dataframe_age['Median_age_by_sex_for_total_population']
main_dataframe['Female_80_85'] = main_dataframe_age['Female_80_85']
main_dataframe['Female_85_>'] = main_dataframe_age['Female_85_>']

# %%
main_dataframe_state['Male_75_79'] = main_dataframe_age_state['Male_75_79']
main_dataframe_state['Male_80_85'] = main_dataframe_age_state['Male_80_85']
main_dataframe_state['Male_85_>'] = main_dataframe_age_state['Male_85_>']
main_dataframe_state['Female_75_79'] = main_dataframe_age_state['Female_75_79']
main_dataframe_state['Female_80_85'] = main_dataframe_age_state['Female_80_85']
main_dataframe_state['Female_85_>'] = main_dataframe_age_state['Female_85_>']
main_dataframe_state['Median_age_by_sex_for_total_population'] = main_dataframe_age_state['Median_age_by_sex_for_total_population']
main_dataframe_state['Median_age_male'] = main_dataframe_age_state['Median_age_male']
main_dataframe_state['Median_age_female'] = main_dataframe_age_state['Median_age_female']

# %%
main_dataframe_state
# Out:
#    State              AreaName  Household_Income  Median_Income  Earnings  \
# 0     AL               Alabama           1851061        1851061   1232880
# 1     AK                Alaska            250235         250235    166629
# 2     AZ               Arizona           2448919        2448919   1602188
# 3     AR              Arkansas           1141480        1141480    757729
# 4     CA            California          12807387       12807387   8800019
# 5     CO              Colorado           2051616        2051616   1318973
# 6     CT           Connecticut           1354713        1354713    894413
# 7     DC  District of Columbia            276546         276546    121101
# 8     DE              Delaware            348051         348051    232569
# 9     FL               Florida           7393262        7393262   4759855
# 10    GA               Georgia           3611706        3611706   2443757
# 11    HI                Hawaii            452030         452030    314721
# ...

# %% [markdown]
# # <font color="#56b2e3"> RACE </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/RACE'

main_dataframe_race = pd.DataFrame()
main_dataframe_race_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B02001_002', 'B02001_003','B02001_004','B02001_005','B02001_006','B02001_007'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_race = main_dataframe_race.append(df_new)

# %%
main_dataframe_race.columns = ['SummaryLevel', 'White_Population', 'Black_Population', 'Indian_Population', 'Asian_Population','Hawaian_Population', 'Other_Population']

# %%
main_dataframe['White_Population'] = main_dataframe_race['White_Population']
main_dataframe['Black_Population'] = main_dataframe_race['Black_Population']
main_dataframe['Indian_Population'] = main_dataframe_race['Indian_Population']
main_dataframe['Asian_Population'] = main_dataframe_race['Asian_Population']
main_dataframe['Hawaian_Population'] = main_dataframe_race['Hawaian_Population']
main_dataframe['Other_Population'] = main_dataframe_race['Other_Population']

# %%
print(main_dataframe)
# Out:
#     SummaryLevel                     AreaName  Household_Income  \
# 12            50     Aitkin County, Minnesota              7640
# 13            50      Anoka County, Minnesota            125260
# 14            50     Becker County, Minnesota             13495
# 15            50   Beltrami County, Minnesota             16906
# 16            50     Benton County, Minnesota             15726
# ..           ...                          ...               ...
# 63            50     Treasure County, Montana               372
# 64            50       Valley County, Montana              3350
# 65            50    Wheatland County, Montana               869
# 66            50       Wibaux County, Montana               496
# 67            50  Yellowstone County, Montana             62459
#
#     Median_Income  Earnings Family_Income  Median_Family_Income  \
# 12           7640      4992         54400                  2648
# 13         125260     90305         86345                 34955
# ...

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B02001_002', 'B02001_003','B02001_004','B02001_005','B02001_006','B02001_007'])
main_dataframe_race_state = main_dataframe_race_state.append(df)
main_dataframe_race_state.columns = ['State', 'AreaName', 'White_Population', 'Black_Population', 'Indian_Population', 'Asian_Population','Hawaian_Population', 'Other_Population']

# %%
main_dataframe_state['White_Population'] = main_dataframe_race_state['White_Population']
main_dataframe_state['Black_Population'] = main_dataframe_race_state['Black_Population']
main_dataframe_state['Indian_Population'] = main_dataframe_race_state['Indian_Population']
main_dataframe_state['Asian_Population'] = main_dataframe_race_state['Asian_Population']
main_dataframe_state['Hawaian_Population'] = main_dataframe_race_state['Hawaian_Population']
main_dataframe_state['Other_Population'] = main_dataframe_race_state['Other_Population']

# %%
print(main_dataframe_state)
# Out:
#    State              AreaName  Household_Income  Median_Income  Earnings  \
# 0     AL               Alabama           1851061        1851061   1232880
# 1     AK                Alaska            250235         250235    166629
# 2     AZ               Arizona           2448919        2448919   1602188
# 3     AR              Arkansas           1141480        1141480    757729
# 4     CA            California          12807387       12807387   8800019
# 5     CO              Colorado           2051616        2051616   1318973
# 6     CT           Connecticut           1354713        1354713    894413
# 7     DC  District of Columbia            276546         276546    121101
# 8     DE              Delaware            348051         348051    232569
# 9     FL               Florida           7393262        7393262   4759855
# 10    GA               Georgia           3611706        3611706   2443757
# 11    HI                Hawaii            452030         452030    314721
# ...

# %% [markdown]
# # <font color="#56b2e3"> POVERTY </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/POVERTY'

main_dataframe_poverty = pd.DataFrame()
main_dataframe_poverty_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B17001_001','B17026_001'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_poverty = main_dataframe_poverty.append(df_new)

# %%
main_dataframe_poverty.columns = ['SummaryLevel', 'Poverty_Status', 'Ratio_Income_Poverty']

# %%
main_dataframe['Poverty_Status'] = main_dataframe_poverty['Poverty_Status']
main_dataframe['Ratio_Income_Poverty'] = main_dataframe_poverty['Ratio_Income_Poverty']

# %%
main_dataframe_poverty_state = pd.DataFrame()

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B17001_001','B17026_001'])
main_dataframe_poverty_state = main_dataframe_poverty_state.append(df)
main_dataframe_poverty_state.columns = ['State', 'AreaName',  'Poverty_Status', 'Ratio_Income_Poverty']

# %%
print(main_dataframe_poverty_state)
# Out:
#    State              AreaName  Poverty_Status  Ratio_Income_Poverty
# 0     AL               Alabama         4720592               1232880
# 1     AK                Alaska          719064                166629
# 2     AZ               Arizona         6573523               1602188
# 3     AR              Arkansas         2881404                757729
# 4     CA            California        37913144               8800019
# 5     CO              Colorado         5241057               1318973
# 6     CT           Connecticut         3479672                894413
# 7     DC  District of Columbia          624954                121101
# 8     DE              Delaware          908973                232569
# 9     FL               Florida        19514334               4759855
# 10    GA               Georgia         9829056               2443757
# 11    HI                Hawaii         1375928                314721
# 12    ID                 Idaho         1604369                408281
# ...

# %%
main_dataframe_state['Poverty_Status'] = main_dataframe_poverty_state['Poverty_Status']
main_dataframe_state['Ratio_Income_Poverty'] = main_dataframe_poverty_state['Ratio_Income_Poverty']

# %% [markdown]
# # <font color="#56b2e3"> MARITAL STATUS </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/MARITALSTATUS'

main_dataframe_marital = pd.DataFrame()
main_dataframe_marital_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B12001_003','B12001_004','B12001_009', 'B12001_010', 'B12001_012','B12001_013','B12001_018', 'B12001_019'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_marital = main_dataframe_marital.append(df_new)

# %%
main_dataframe_marital.columns = ['SummaryLevel', 'Male_Never_Married', 'Male_Married', 'Male_Widowed', 'Male_Divorced', 'Female_Never_Married', 'Female_Married', 'Female_Widowed', 'Female_Divorced']

# %%
main_dataframe['Male_Never_Married'] = main_dataframe_marital['Male_Never_Married']
main_dataframe['Male_Married'] = main_dataframe_marital['Male_Married']
main_dataframe['Male_Widowed'] = main_dataframe_marital['Male_Widowed']
main_dataframe['Male_Divorced'] = main_dataframe_marital['Male_Divorced']
main_dataframe['Female_Never_Married'] = main_dataframe_marital['Female_Never_Married']
main_dataframe['Female_Married'] = main_dataframe_marital['Female_Married']
main_dataframe['Female_Widowed'] = main_dataframe_marital['Female_Widowed']
main_dataframe['Female_Divorced'] = main_dataframe_marital['Female_Divorced']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B12001_003','B12001_004','B12001_009', 'B12001_010', 'B12001_012','B12001_013','B12001_018', 'B12001_019'])
main_dataframe_marital_state = main_dataframe_marital_state.append(df)
main_dataframe_marital_state.columns = ['State', 'AreaName',  'Male_Never_Married', 'Male_Married', 'Male_Widowed', 'Male_Divorced', 'Female_Never_Married', 'Female_Married', 'Female_Widowed', 'Female_Divorced']

# %%
main_dataframe_state['Male_Never_Married'] = main_dataframe_marital_state['Male_Never_Married']
main_dataframe_state['Male_Married'] = main_dataframe_marital_state['Male_Married']
main_dataframe_state['Male_Widowed'] = main_dataframe_marital_state['Male_Widowed']
main_dataframe_state['Male_Divorced'] = main_dataframe_marital_state['Male_Divorced']
main_dataframe_state['Female_Never_Married'] = main_dataframe_marital_state['Female_Never_Married']
main_dataframe_state['Female_Married'] = main_dataframe_marital_state['Female_Married']
main_dataframe_state['Female_Widowed'] = main_dataframe_marital_state['Female_Widowed']
main_dataframe_state['Female_Divorced'] = main_dataframe_marital_state['Female_Divorced']

# %% [markdown]
# # <font color="#56b2e3"> HEALTHCARE </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/HEALTHINSURANCE'

main_dataframe_health = pd.DataFrame()
main_dataframe_health_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B27001_001', 'B27002_001'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_health = main_dataframe_health.append(df_new)

# %%
main_dataframe_health.columns = ['SummaryLevel', 'Healthcare_Public', 'Healthcare_Private']

# %%
main_dataframe['Healthcare_Public'] = main_dataframe_health['Healthcare_Public']
main_dataframe['Healthcare_Private'] = main_dataframe_health['Healthcare_Private']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B27001_001', 'B27002_001'])
main_dataframe_health_state = main_dataframe_health_state.append(df)
main_dataframe_health_state.columns = ['State', 'AreaName', 'Healthcare_Public', 'Healthcare_Private']

# %%
main_dataframe_state['Healthcare_Public'] = main_dataframe_health_state['Healthcare_Public']
main_dataframe_state['Healthcare_Private'] = main_dataframe_health_state['Healthcare_Private']

# %% [markdown]
# # <font color="#56b2e3"> EMPLOYMENT STATUS </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/EMPLOYMENT'

main_dataframe_emp = pd.DataFrame()
main_dataframe_emp_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B23001_001', 'B23001_008', 'B23001_015', 'B23001_022', 'B23001_029', 'B23001_036', 'B23001_043', 'B23001_050', 'B23001_057', 'B23001_064', 'B23001_071', 'B23001_076', 'B23001_081', 'B23001_086', 'B23001_094', 'B23001_101', 'B23001_108', 'B23001_115', 'B23001_122', 'B23001_129', 'B23001_136', 'B23001_143', 'B23001_150', 'B23001_157', 'B23001_162', 'B23001_167', 'B23001_172'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_emp = main_dataframe_emp.append(df_new)

# %%
main_dataframe_emp.columns = ['SummaryLevel', 'employment_total', '16_19_male_unemployment', '20_21_male_unemployment', '22_24_male_unemployment', '25_29_male_unemployment', '30_34_malel_unemployment', '35_44_male_unemployment', '45_54_male_unemployment', '55_59_male_unemployment', '60_61_male_unemployment', '62_64_male_unemployment', '65_69_male_unemployment', '70_74_male_unemployment', '75_>_male_unemployment', '16_19_female_unemployment', '20_21_female_unemployment', '22_24_female_unemployment', '25_29_female_unemployment', '30_34_female_unemployment', '35_44_female_unemployment', '45_54_female_unemployment', '55_59_female_unemployment', '60_61_female_unemployment', '62_64_female_unemployment', '65_69_female_unemployment', '70_74_female_unemployment', '75_>_female_unemployment']

# %%
main_dataframe['employment_total'] = main_dataframe_emp['employment_total']
main_dataframe['16_19_male_unemployment'] = main_dataframe_emp['16_19_male_unemployment']
main_dataframe['20_21_male_unemployment'] = main_dataframe_emp['20_21_male_unemployment']
main_dataframe['22_24_male_unemployment'] = main_dataframe_emp['22_24_male_unemployment']
main_dataframe['25_29_male_unemployment'] = main_dataframe_emp['25_29_male_unemployment']
main_dataframe['30_34_malel_unemployment'] = main_dataframe_emp['30_34_malel_unemployment']
main_dataframe['35_44_male_unemployment'] = main_dataframe_emp['35_44_male_unemployment']
main_dataframe['45_54_male_unemployment'] = main_dataframe_emp['45_54_male_unemployment']
main_dataframe['55_59_male_unemployment'] = main_dataframe_emp['55_59_male_unemployment']
main_dataframe['60_61_male_unemployment'] = main_dataframe_emp['60_61_male_unemployment']
main_dataframe['62_64_male_unemployment'] = main_dataframe_emp['62_64_male_unemployment']
main_dataframe['65_69_male_unemployment'] = main_dataframe_emp['65_69_male_unemployment']
main_dataframe['70_74_male_unemployment'] = main_dataframe_emp['70_74_male_unemployment']
main_dataframe['75_>_male_unemployment'] = main_dataframe_emp['75_>_male_unemployment']
main_dataframe['16_19_female_unemployment'] = main_dataframe_emp['16_19_female_unemployment']
main_dataframe['20_21_female_unemployment'] = main_dataframe_emp['20_21_female_unemployment']
main_dataframe['22_24 _female_unemployment'] = main_dataframe_emp['22_24 _female_unemployment']

main_dataframe['25_29_female_unemployment'] = main_dataframe_emp['25_29_female_unemployment']
main_dataframe['30_34_female_unemployment'] = main_dataframe_emp['30_34_female_unemployment']
main_dataframe['35_44_female_unemployment'] = main_dataframe_emp['35_44_female_unemployment']
main_dataframe['45_54_female_unemployment'] = main_dataframe_emp['45_54_female_unemployment']
main_dataframe['55_59_female_unemployment'] = main_dataframe_emp['55_59_female_unemployment']
main_dataframe['60_61_female_unemployment'] = main_dataframe_emp['60_61_female_unemployment']
main_dataframe['62_64_female_unemployment'] = main_dataframe_emp['62_64_female_unemployment']
main_dataframe['65_69_female_unemployment'] = main_dataframe_emp['65_69_female_unemployment']
main_dataframe['70_74_female_unemployment'] = main_dataframe_emp['70_74_female_unemployment']
main_dataframe['75_>_female_unemployment'] = main_dataframe_emp['75_>_female_unemployment']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B23001_001', 'B23001_008', 'B23001_015', 'B23001_022', 'B23001_029', 'B23001_036', 'B23001_043', 'B23001_050', 'B23001_057', 'B23001_064', 'B23001_071', 'B23001_076', 'B23001_081', 'B23001_086', 'B23001_094', 'B23001_101', 'B23001_108', 'B23001_115', 'B23001_122', 'B23001_129', 'B23001_136', 'B23001_143', 'B23001_150', 'B23001_157', 'B23001_162', 'B23001_167', 'B23001_172'])
main_dataframe_emp_state = main_dataframe_emp_state.append(df)
main_dataframe_emp_state.columns = ['State', 'AreaName', 'employment_total', '16_19_male_unemployment', '20_21_male_unemployment', '22_24_male_unemployment', '25_29_male_unemployment', '30_34_malel_unemployment', '35_44_male_unemployment', '45_54_male_unemployment', '55_59_male_unemployment', '60_61_male_unemployment', '62_64_male_unemployment', '65_69_male_unemployment', '70_74_male_unemployment', '75_>_male_unemployment', '16_19_female_unemployment', '20_21_female_unemployment', '22_24_female_unemployment', '25_29_female_unemployment', '30_34_female_unemployment', '35_44_female_unemployment', '45_54_female_unemployment', '55_59_female_unemployment', '60_61_female_unemployment', '62_64_female_unemployment', '65_69_female_unemployment', '70_74_female_unemployment', '75_>_female_unemployment']

# %%
main_dataframe_state['employment_total'] = main_dataframe_emp_state['employment_total']
main_dataframe_state['16_19_male_unemployment'] = main_dataframe_emp_state['16_19_male_unemployment']
main_dataframe_state['20_21_male_unemployment'] = main_dataframe_emp_state['20_21_male_unemployment']
main_dataframe_state['22_24_male_unemployment'] = main_dataframe_emp_state['22_24_male_unemployment']
main_dataframe_state['25_29_male_unemployment'] = main_dataframe_emp_state['25_29_male_unemployment']
main_dataframe_state['30_34_malel_unemployment'] = main_dataframe_emp_state['30_34_malel_unemployment']
main_dataframe_state['35_44_male_unemployment'] = main_dataframe_emp_state['35_44_male_unemployment']
main_dataframe_state['45_54_male_unemployment'] = main_dataframe_emp_state['45_54_male_unemployment']
main_dataframe_state['55_59_male_unemployment'] = main_dataframe_emp_state['55_59_male_unemployment']
main_dataframe_state['60_61_male_unemployment'] = main_dataframe_emp_state['60_61_male_unemployment']
main_dataframe_state['62_64_male_unemployment'] = main_dataframe_emp_state['62_64_male_unemployment']
main_dataframe_state['65_69_male_unemployment'] = main_dataframe_emp_state['65_69_male_unemployment']
main_dataframe_state['70_74_male_unemployment'] = main_dataframe_emp_state['70_74_male_unemployment']
main_dataframe_state['75_>_male_unemployment'] = main_dataframe_emp_state['75_>_male_unemployment']
main_dataframe_state['16_19_female_unemployment'] = main_dataframe_emp_state['16_19_female_unemployment']
main_dataframe_state['20_21_female_unemployment'] = main_dataframe_emp_state['20_21_female_unemployment']
main_dataframe_state['22_24 _female_unemployment'] = main_dataframe_emp_state['22_24_female_unemployment']

main_dataframe_state['25_29_female_unemployment'] = main_dataframe_emp_state['25_29_female_unemployment']
main_dataframe_state['30_34_female_unemployment'] = main_dataframe_emp_state['30_34_female_unemployment']
main_dataframe_state['35_44_female_unemployment'] = main_dataframe_emp_state['35_44_female_unemployment']
main_dataframe_state['45_54_female_unemployment'] = main_dataframe_emp_state['45_54_female_unemployment']
main_dataframe_state['55_59_female_unemployment'] = main_dataframe_emp_state['55_59_female_unemployment']
main_dataframe_state['60_61_female_unemployment'] = main_dataframe_emp_state['60_61_female_unemployment']
main_dataframe_state['62_64_female_unemployment'] = main_dataframe_emp_state['62_64_female_unemployment']
main_dataframe_state['65_69_female_unemployment'] = main_dataframe_emp_state['65_69_female_unemployment']
main_dataframe_state['70_74_female_unemployment'] = main_dataframe_emp_state['70_74_female_unemployment']
main_dataframe_state['75_>_female_unemployment'] = main_dataframe_emp_state['75_>_female_unemployment']

# %% [markdown]
# # <font color="#56b2e3"> EDUCATION </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/EDUCATION'

main_dataframe_edu = pd.DataFrame()
main_dataframe_edu_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B15001_001', 'B15012_001'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_edu = main_dataframe_edu.append(df_new)

# %%
main_dataframe_edu.columns = ['SummaryLevel', 'Education_Attainment', 'Total_fields_of_bachelors_degrees_reported']

# %%
main_dataframe['Education_Attainment'] = main_dataframe_edu['Education_Attainment']
main_dataframe['Education_Bachelor'] = main_dataframe_edu['Total_fields_of_bachelors_degrees_reported']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B15001_001', 'B15012_001'])
main_dataframe_edu_state = main_dataframe_edu_state.append(df)
main_dataframe_edu_state.columns = ['State', 'AreaName', 'Education_Attainment', 'Total_fields_of_bachelors_degrees_reported']

# %%
main_dataframe_state['Education_Attainment'] = main_dataframe_edu_state['Education_Attainment']
main_dataframe_state['Total_fields_of_bachelors_degrees_reported'] = main_dataframe_edu_state['Total_fields_of_bachelors_degrees_reported']

# %% [markdown]
# # <font color="#56b2e3"> FOREIGN BIRTH </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/FOREIGNBIRTH'

main_dataframe_fb = pd.DataFrame()
main_dataframe_fb_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B05001_001', 'B05014_001'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_fb = main_dataframe_fb.append(df_new)

# %%
main_dataframe_fb.columns = ['SummaryLevel', 'Nativity_Citizenship', 'Foreign_born_population']

# %%
main_dataframe['Nativity_Citizenship'] = main_dataframe_fb['Nativity_Citizenship']
main_dataframe['Foreign_born_population'] = main_dataframe_fb['Foreign_born_population']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B05001_001', 'B05014_001'])
main_dataframe_fb_state = main_dataframe_fb_state.append(df)
main_dataframe_fb_state.columns = ['State', 'AreaName', 'Nativity_Citizenship', 'Foreign_born_population']

# %%
main_dataframe_state['Nativity_Citizenship'] = main_dataframe_fb_state['Nativity_Citizenship']
main_dataframe_state['Foreign_born_population'] = main_dataframe_fb_state['Foreign_born_population']

# %% [markdown]
# # <font color="#56b2e3"> LATIN ORIGIN </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/HISPANIC'

main_dataframe_h = pd.DataFrame()
main_dataframe_h_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B03001_001'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_h = main_dataframe_h.append(df_new)

# %%
main_dataframe_h.columns = ['SummaryLevel', 'Hispanic_Population']

# %%
main_dataframe['Hispanic_Population'] = main_dataframe_h['Hispanic_Population']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B03001_001'])
main_dataframe_h_state = main_dataframe_h_state.append(df)
main_dataframe_h_state.columns = ['State', 'AreaName', 'Hispanic_Population']

# %%
main_dataframe_state['Hispanic_Population'] = main_dataframe_h_state['Hispanic_Population']

# %%
print(main_dataframe)
# Out:
#     SummaryLevel                     AreaName  Household_Income  \
# 12            50     Aitkin County, Minnesota              7640
# 13            50      Anoka County, Minnesota            125260
# 14            50     Becker County, Minnesota             13495
# 15            50   Beltrami County, Minnesota             16906
# 16            50     Benton County, Minnesota             15726
# ..           ...                          ...               ...
# 63            50     Treasure County, Montana               372
# 64            50       Valley County, Montana              3350
# 65            50    Wheatland County, Montana               869
# 66            50       Wibaux County, Montana               496
# 67            50  Yellowstone County, Montana             62459
#
#     Median_Income  Earnings Family_Income  Median_Family_Income  \
# 12           7640      4992         54400                  2648
# 13         125260     90305         86345                 34955
# ...

# %%
print(main_dataframe_state)
# Out:
#    State              AreaName  Household_Income  Median_Income  Earnings  \
# 0     AL               Alabama           1851061        1851061   1232880
# 1     AK                Alaska            250235         250235    166629
# 2     AZ               Arizona           2448919        2448919   1602188
# 3     AR              Arkansas           1141480        1141480    757729
# 4     CA            California          12807387       12807387   8800019
# 5     CO              Colorado           2051616        2051616   1318973
# 6     CT           Connecticut           1354713        1354713    894413
# 7     DC  District of Columbia            276546         276546    121101
# 8     DE              Delaware            348051         348051    232569
# 9     FL               Florida           7393262        7393262   4759855
# 10    GA               Georgia           3611706        3611706   2443757
# 11    HI                Hawaii            452030         452030    314721
# ...

# %%
main_dataframe[['County','State']] = main_dataframe.AreaName.str.split(", ",expand=True)

# %% [markdown]
# # <font color="#56b2e3"> CHILDREN </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/CHILDREN'

main_dataframe_ch = pd.DataFrame()
main_dataframe_ch_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B09001_001'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_ch = main_dataframe_ch.append(df_new)

# %%
main_dataframe_ch.columns = ['SummaryLevel', 'Children']

# %%
main_dataframe['Children'] = main_dataframe_ch['Children']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B09001_001'])
main_dataframe_ch_state = main_dataframe_ch_state.append(df)
main_dataframe_ch_state.columns = ['State', 'AreaName', 'Children']

# %%
main_dataframe_state['Children'] = main_dataframe_ch_state['Children']

# %% [markdown]
# # <font color="#56b2e3"> JOURNEY TO WORK </font>

# %%
directory = '/Users/andresreyes/Downloads/ACS/JOURNEY'

main_dataframe_j = pd.DataFrame()
main_dataframe_j_state = pd.DataFrame()
for filename in os.listdir(directory):
    if(len(filename) == 6): 
        df = pd.read_csv(os.path.join(directory, filename),low_memory=False, usecols=['SummaryLevel','B08006_003', 'B08006_004', 'B08006_008', 'B08006_017'])
        df_new = df[df['SummaryLevel'] == 50]
        main_dataframe_j = main_dataframe_j.append(df_new)

# %%
main_dataframe_j.columns = ['SummaryLevel', 'Car_drove_alone', 'Car_pooled', 'Public_transportation', 'Worked_at_home']

# %%
main_dataframe['Car_drove_alone'] = main_dataframe_j['Car_drove_alone']
main_dataframe['Car_pooled'] = main_dataframe_j['Car_pooled']
main_dataframe['Public_transportation'] = main_dataframe_j['Public_transportation']
main_dataframe['Worked_at_home'] = main_dataframe_j['Worked_at_home']

# %%
df = pd.read_csv(os.path.join(directory, 'USA_All_States.csv'), usecols=["State", "AreaName", 'B08006_003', 'B08006_004', 'B08006_008', 'B08006_017'])
main_dataframe_j_state = main_dataframe_j_state.append(df)
main_dataframe_j_state.columns = ['State', 'AreaName', 'Car_drove_alone', 'Car_pooled', 'Public_transportation', 'Worked_at_home']

# %%
main_dataframe_state['Car_drove_alone'] = main_dataframe_j_state['Car_drove_alone']
main_dataframe_state['Car_pooled'] = main_dataframe_j_state['Car_pooled']
main_dataframe_state['Public_transportation'] = main_dataframe_j_state['Public_transportation']
main_dataframe_state['Worked_at_home'] = main_dataframe_j_state['Worked_at_home']

# %%
# import the module
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost:3307/{db}"
                       .format(user="admin",
                               pw="admin123",
                               db="covid"))

# %%
print(engine)
# Out:
# Engine(mysql+pymysql://admin:***@localhost:3307/covid)

# %%
main_dataframe["County"] = main_dataframe.County.str.replace("County", "")

# %%
main_dataframe["County"] = main_dataframe.County.str.replace("Municipio", "")

# %%
print(main_dataframe)
# Out:
#     SummaryLevel                     AreaName  Household_Income  \
# 12            50     Aitkin County, Minnesota              7640
# 13            50      Anoka County, Minnesota            125260
# 14            50     Becker County, Minnesota             13495
# 15            50   Beltrami County, Minnesota             16906
# 16            50     Benton County, Minnesota             15726
# ..           ...                          ...               ...
# 63            50     Treasure County, Montana               372
# 64            50       Valley County, Montana              3350
# 65            50    Wheatland County, Montana               869
# 66            50       Wibaux County, Montana               496
# 67            50  Yellowstone County, Montana             62459
#
#     Median_Income  Earnings Family_Income  Median_Family_Income  \
# 12           7640      4992         54400                  2648
# 13         125260     90305         86345                 34955
# ...

# %%
# Insert whole DataFrame into MySQL
main_dataframe.to_sql('acs_dataset_county', con = engine, if_exists = 'append', chunksize = 1000)

# %%
main_dataframe_state.to_sql('acs_dataset_state', con = engine, if_exists = 'append', chunksize = 1000)
